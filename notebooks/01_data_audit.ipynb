# %% [markdown]
# # 01 Data Audit
#
# Quick quality check on all raw and interim data files.
#
# > Run this notebook after python scripts/01_fetch_data.py to verify ingestion.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../src")

# TODO: import cropshield data modules once implemented

# %% [markdown]
# ## NASS Yield Data
#
# Check row counts, year range, missingness, and suppressed records.

# %%
# TODO: Load data/interim/nass_yield_clean.csv and audit
# nass = pd.read_csv("../data/interim/nass_yield_clean.csv")
# print(nass.info())
# print(nass.describe())
print("NASS file not yet available. Run scripts/01_fetch_data.py first.")

# %% [markdown]
# ## Weather Data
#
# Check coverage by county and year.

# %%
# TODO: Load and audit weather data
print("Weather file not yet available.")

# %% [markdown]
# ## Drought Monitor Data
#
# Check weekly coverage and category distributions.

# %%
# TODO: Load and audit drought data
print("Drought file not yet available.")
