# %% [markdown]
# # 03 Model Results
#
# Model evaluation metrics, prediction plots, and interpretability analysis.
#
# > Run after python scripts/04_evaluate_model.py.

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../src")

# TODO: Load reports/metrics.json and data/processed/predictions.csv
print("Run make evaluate to generate model results.")

# %% [markdown]
# ## Metrics Summary
#
# Comparison of baseline vs ML model metrics (RMSE, MAE, R²).

# %%
# TODO: Display metrics from reports/metrics.json

# %% [markdown]
# ## Predicted vs Actual

# %%
# TODO: Load and show reports/figures/predicted_vs_actual.png

# %% [markdown]
# ## Feature Importance

# %%
# TODO: Load and show reports/figures/feature_importance.png

# %% [markdown]
# ## Residuals by Year

# %%
# TODO: Load and show reports/figures/residuals_by_year.png

# %% [markdown]
# ## Limitations
#
# - County-level aggregation hides farm-level variation.
# - Weather approximated at county centroids.
# - Feature importance ≠ causation.
# - Results may not generalise to unseen states or climate years.
