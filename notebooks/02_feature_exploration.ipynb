# %% [markdown]
# # 02 Feature Exploration
#
# Distributions, correlations, and year-over-year patterns in engineered features.
#
# > Run after python scripts/02_build_features.py.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.insert(0, "../src")

sns.set_theme(style="whitegrid")

# TODO: Load data/processed/modeling_panel.csv
print("Modeling panel not yet available. Run scripts/02_build_features.py first.")

# %% [markdown]
# ## Yield Anomaly Distribution

# %%
# TODO: Plot yield_anomaly distribution by state and year

# %% [markdown]
# ## Weather Feature Distributions

# %%
# TODO: Plot key weather feature distributions

# %% [markdown]
# ## Drought Severity vs Yield Anomaly

# %%
# TODO: Scatter plot of d2_plus_weeks vs yield_anomaly

# %% [markdown]
# ## Correlation Heatmap

# %%
# TODO: Correlation matrix of all numeric features
